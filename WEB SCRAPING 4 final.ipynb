# %% [markdown]
# 9. Scrape the details most watched tv series of all time from imdb.com.
#  Url = https://www.imdb.com/list/ls095964455/
# You have to find the following details:
# A) Name
# B) Year span
# C) Genre
# D) Run time
# E) Ratings
# F) Votes

# %%
# Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

# Importing selenium webdriver 
from selenium import webdriver

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

#Importing requests
import requests

# importing regex
import re

# %%
driver=webdriver.Chrome(r"C:\Users\HP\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver=webdriver.Chrome("chromedriver.exe")

# %%
time.sleep(4)

# %%
url = "https://www.imdb.com/list/ls095964455/"
driver.get(url)

# %%
Name = []
Year_span = []
Genre = []
Run_time = []
Ratings = []
Votes = []

# %%
time.sleep(2)

# %%
Names = driver.find_elements_by_xpath("//a[contains(text(),'')]")
Names
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="f1110c1d-d506-43f1-a10b-502818817348")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="7a9247f4-8425-4c44-9cb8-d460aea9fc23")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="7d8bf461-05ef-4e9b-b871-a32fe7890b68")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="6fd802c5-f662-437f-9a80-ea4d7c63bf14")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="566d11e9-123e-4c69-bb43-efb4b393b3c2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="49a97278-7ef1-4aeb-9046-63fb32e82f64")>,
# ...

# %%
for i in Names:
    Name.append(i.text)

# %%
Name
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Watchlist',
#  'Sign In',
#  '',
#  '',
#  '',
#  'zsoka-61620',
#  '',
#  '',
#  '',
#  '',
#  'Game of Thrones',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Emilia Clarke',
#  'Peter Dinklage',
#  'Kit Harington',
#  'Lena Headey',
#  '',
#  'Stranger Things',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Millie Bobby Brown',
#  'Finn Wolfhard',
#  'Winona Ryder',
#  'David Harbour',
#  '',
#  'The Walking Dead',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Andrew Lincoln',
#  'Norman Reedus',
# ...

# %%
Years = driver.find_elements_by_xpath("//span[@class='lister-item-year text-muted unbold']")
Years
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="7e436b8c-1d59-4fa4-8fdd-7fa5598c169d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="b49e2405-692d-4ff0-b9cd-c4fb92bb7114")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="cb96e6c5-02fa-4c10-a15b-b3e128bdaf5e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="89b37576-cb09-4363-ac26-347b79f09f6c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="997d63cb-2985-4fb4-a7e0-d7d66301bd7f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="d9cb6cac-0b85-4405-8f8f-33f13637d331")>,
# ...

# %%
for i in Years:
    Year_span.append(i.text)

# %%
Year_span
# Out:
# ['(2011–2019)',
#  '(2016– )',
#  '(2010–2022)',
#  '(2017–2020)',
#  '(2014–2020)',
#  '(2013–2019)',
#  '(2017– )',
#  '(2005– )',
#  '(2014– )',
#  '(2012–2020)',
#  '(2017–2021)',
#  '(2007–2019)',
#  '(2011– )',
#  '(2010–2017)',
#  '(2013–2020)',
#  '(2010–2017)',
#  '(2009–2017)',
#  '(2011– )',
#  '(2008–2013)',
#  '(2016–2021)',
#  '(2005–2020)',
#  '(2005–2017)',
#  '(2014–2020)',
#  '(2011–2017)',
#  '(1989– )',
#  '(2011–2018)',
#  '(2015–2017)',
#  '(2015–2018)',
#  '(1994–2004)',
#  '(2005–2014)',
#  '(2011–2019)',
#  '(2015–2019)',
#  '(2013–2018)',
#  '(2015–2021)',
#  '(2007–2012)',
#  '(2015–2018)',
#  '(2014–2019)',
#  '(2016– )',
#  '(2015–2019)',
#  '(2009–2020)',
#  '(2013– )',
#  '(2016–2019)',
#  '(2017–2019)',
#  '(2013–2018)',
#  '(2017–2020)',
#  '(2018– )',
#  '(2019– )',
#  '(2011–2021)',
#  '(2011–2018)',
#  '(2013–2020)',
#  '(2018– )',
#  '(2006–2013)',
#  '(2015– )',
#  '(1999– )',
#  '(2013– )',
#  '(2004–2010)',
#  '(2013– )',
#  '(2004–2012)',
# ...

# %%
Gen = driver.find_elements_by_xpath("//span[@class='genre']")
Gen
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="38538d28-12c8-44b6-9d59-a990693d5029")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="7f637d62-72e5-43c1-a7c9-884a69437a1a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="ac177af7-f815-4181-a408-e93cdf5e82a4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="d7a67252-3098-4d85-a144-527143afb946")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="2ea088a0-8add-4731-ae82-de5bb2a01335")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="5890e31d-6d69-423f-8c39-e83f35862a1d")>,
# ...

# %%
for i in Gen:
    Genre.append(i.text)

# %%
Genre
# Out:
# ['Action, Adventure, Drama',
#  'Drama, Fantasy, Horror',
#  'Drama, Horror, Thriller',
#  'Drama, Mystery, Thriller',
#  'Drama, Mystery, Sci-Fi',
#  'Comedy, Crime, Drama',
#  'Crime, Drama, Mystery',
#  'Drama, Romance',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Crime',
#  'Action, Crime, Mystery',
#  'Comedy, Romance',
#  'Drama, Sci-Fi, Thriller',
#  'Crime, Drama, Mystery',
#  'Action, Adventure, Drama',
#  'Drama, Mystery, Romance',
#  'Drama, Fantasy, Horror',
#  'Drama, Horror, Thriller',
#  'Crime, Drama, Thriller',
#  'Crime, Drama, Fantasy',
#  'Drama, Fantasy, Horror',
#  'Action, Crime, Drama',
#  'Crime, Drama, Mystery',
#  'Action, Drama, Fantasy',
#  'Animation, Comedy',
#  'Adventure, Fantasy, Romance',
#  'Biography, Crime, Drama',
#  'Action, Crime, Drama',
#  'Comedy, Romance',
#  'Comedy, Romance',
#  'Comedy, Drama',
#  'Crime, Drama, Thriller',
#  'Drama, Fantasy, Horror',
#  'Action, Adventure, Drama',
#  'Drama, Romance',
# ...

# %% [markdown]
# Run_time = []
# Ratings = []
# Votes = []

# %%
time = driver.find_elements_by_xpath("//span[@class='runtime']")
time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="d8f5a309-e5a1-437f-9cd0-45a9dbf528c4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="4adfd188-34c7-4488-9b9b-2926d2210e3c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="927c5317-c93a-4206-b787-ca64df45d92f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="c11187cf-4a71-4955-aecc-5292e5b68985")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="fc6ccdf8-b8fa-4ef2-91d8-01f5a27202d6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="2d739fe8-bea4-4999-9771-d2cc2e977f81")>,
# ...

# %%
for i in time:
    Run_time .append(i.text)

# %%
Run_time
# Out:
# ['57 min',
#  '51 min',
#  '44 min',
#  '60 min',
#  '43 min',
#  '59 min',
#  '45 min',
#  '41 min',
#  '43 min',
#  '42 min',
#  '70 min',
#  '22 min',
#  '60 min',
#  '88 min',
#  '44 min',
#  '44 min',
#  '43 min',
#  '60 min',
#  '49 min',
#  '42 min',
#  '44 min',
#  '44 min',
#  '43 min',
#  '41 min',
#  '22 min',
#  '60 min',
#  '49 min',
#  '54 min',
#  '22 min',
#  '22 min',
#  '44 min',
#  '49 min',
#  '45 min',
#  '43 min',
#  '42 min',
#  '60 min',
#  '42 min',
#  '62 min',
#  '56 min',
#  '22 min',
#  '23 min',
#  '42 min',
#  '25 min',
#  '51 min',
#  '60 min',
#  '60 min',
#  '45 min',
#  '46 min',
#  '22 min',
#  '45 min',
#  '45 min',
#  '53 min',
#  '44 min',
#  '22 min',
#  '43 min',
#  '44 min',
#  '60 min',
#  '44 min',
#  '42 min',
#  '44 min',
#  '55 min',
#  '42 min',
#  '42 min',
#  '60 min',
#  '60 min',
#  '41 min',
#  '60 min',
#  '44 min',
#  '22 min',
#  '22 min',
#  '43 min',
#  '60 min',
#  '55 min',
#  '60 min',
#  '45 min',
#  '46 min',
# ...

# %%
Rating = driver.find_elements_by_xpath("//span[@class='ipl-rating-star__rating']")
Rating
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="fee03e5b-66c4-4e35-85ae-c89370325900")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="a4b3e26e-e45f-41e4-9a5d-96714a78cae8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="bd93e884-e8f1-41ba-92f9-add47ac4b0e9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="a257edb9-a356-4081-b73d-54a3e21d4c1a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="8ba77efc-1bd4-4713-a76a-ca868b07696e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="b6c3c94e-099b-4d7a-b645-e32ba3d33061")>,
# ...

# %%
for i in Rating:
    if i.text is None :
        Ratings.append("--") 
    else:
        Ratings.append(i.text)

# %%
Ratings
# Out:
# [' 9 . 2 ',
#  ' ',
#  ' R a t e ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' 8 . 7 ',
#  ' ',
#  ' R a t e ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' 8 . 2 ',
#  ' ',
#  ' R a t e ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' 7 . 6 ',
#  ' ',
#  ' R a t e ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' 7 . 6 ',
#  ' ',
#  ' R a t e ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' 8 ',
# ...

# %%
Vote = driver.find_elements_by_xpath("//span[@name='nv']")
Vote
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="6c885137-7aa2-45e7-8ad0-38b06d49ce82")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="5fa75718-7c22-4c7a-b693-f5d9be592d8a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="9e54008b-de5e-404b-8b9c-e0db81a81703")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="c3f921ff-6f48-477d-800a-911acca0f911")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="97649de9-c302-4eba-95fa-7c5d90eb8827")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="46d39ff9-5a27-4872-8801-55fee7b714de")>,
# ...

# %%
for i in Vote:
    Votes.append(i.text)

# %%
Votes
# Out:
# ['1,867,494',
#  '903,079',
#  '894,584',
#  '269,243',
#  '229,505',
#  '286,197',
#  '128,323',
#  '269,745',
#  '323,619',
#  '416,705',
#  '370,659',
#  '748,444',
#  '475,734',
#  '847,104',
#  '466,589',
#  '156,963',
#  '295,938',
#  '289,982',
#  '1,573,449',
#  '271,346',
#  '407,423',
#  '496,336',
#  '137,706',
#  '134,511',
#  '378,794',
#  '213,751',
#  '379,664',
#  '378,656',
#  '892,822',
#  '629,344',
#  '377,302',
#  '349,366',
#  '123,921',
#  '116,437',
#  '161,249',
#  '145,082',
#  '217,837',
#  '449,136',
#  '199,599',
#  '383,125',
#  '426,388',
#  '56,938',
#  '160,846',
#  '479,464',
#  '319,128',
#  '61,937',
#  '182,187',
#  '215,010',
#  '202,450',
#  '206,508',
#  '161,247',
#  '671,848',
#  '119,004',
#  '314,822',
#  '216,313',
#  '516,286',
#  '404,007',
#  '429,104',
#  '58,622',
#  '105,256',
#  '324,116',
#  '68,962',
#  '97,023',
#  '200,253',
#  '83,773',
#  '75,164',
#  '42,648',
#  '140,865',
#  '342,972',
#  '256,365',
#  '103,210',
# ...

# %%
df=pd.DataFrame({"Name":Name[0:100],
                "Year_span":Year_span[0:100],
                "Genre":Genre[0:100],
                "Run_time":Run_time[0:100],
                "Ratings":Ratings[0:100],
                 "Votes":Votes[0:100],})
df
# Out:
#                 Name    Year_span                     Genre Run_time  \
# 0                     (2011–2019)  Action, Adventure, Drama   57 min
# 1                        (2016– )    Drama, Fantasy, Horror   51 min
# 2                     (2010–2022)   Drama, Horror, Thriller   44 min
# 3                     (2017–2020)  Drama, Mystery, Thriller   60 min
# 4                     (2014–2020)    Drama, Mystery, Sci-Fi   43 min
# ..               ...          ...                       ...      ...
# 95     David Harbour  (2013–2017)            Drama, Fantasy   42 min
# 96                    (2017–2019)  Adventure, Comedy, Drama   50 min
# 97  The Walking Dead  (2005–2020)     Crime, Drama, Mystery   42 min
# 98                    (2015–2019)      Comedy, Crime, Drama   45 min
# 99                         (2018)    Drama, Horror, Mystery  572 min
#
#       Ratings      Votes
# 0      9 . 2   1,867,494
# 1                903,079
# 2    R a t e     894,584
# 3                269,243
# ...

# %% [markdown]
# 8. Scrape the details of Highest selling novels. Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare/ You have to find the following details: A) Book name B) Author name C) Volumes sold D) Publisher E) Genre
# Data not found in given url

# %% [markdown]
# 7. Scrape the details of Data science recruiters from naukri.com.
# Url = https://www.naukri.com/
# You have to find the following details:
# A) Name
# B) Designation
# C) Company
# D) Skills they hire for
# E) Location
# Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and
# click on search. All this should be done through code

# %%
url = "https://www.naukri.com/data-science-recruiters"
driver.get(url)

# %%
search_name=driver.find_elements_by_xpath("//span[@class='fl ellipsis']")
search_name
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="cedd0064-6f2f-4821-b3b2-cbb9f367d38e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="602d9da0-96ea-45b7-b3b8-e69bfc3b682a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="7b4424b3-a3c6-4537-af0d-b9d06bd50a6c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="44553ec2-185b-40e3-87f9-67efa24f9c1b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="31a5198b-c970-40f5-8240-9576322a336f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="b3fe3763-454c-4068-a936-781cfe4558bd")>,
# ...

# %%
name = []

# %%
for i in search_name:
    name.append(i.text)
name
# Out:
# ['Aakash Harit',
#  'shravan Kumar Gaddam',
#  'MARSIAN Technologies LLP',
#  'Anik Agrawal',
#  'subhas patel',
#  'Abhishek - Only Analytics Hiring - India and',
#  'Institute for Financial Management and Resear',
#  'Balu Ramesh',
#  'Asif Lucknowi',
#  'InstaFinancials',
#  'Priyanka Akiri',
#  'Kalpana Dumpala',
#  'Mubarak',
#  'Kushal Rastogi',
#  'Ruchi Dhote',
#  'Mahesh Babu Channa',
#  'Kapil Devang',
#  'Manisha Yadav',
#  'Riya Rajesh',
#  'Rashmi Bhattacharjee',
#  'Faizan Kareem',
#  'Rithika dadwal',
#  'Sandhya Khandagale',
#  'Shaun Rao',
#  'Azahar Shaikh',
#  'Manas',
#  'kumar',
#  'Sunil Vedula',
#  'Rajat Kumar',
#  'Priya Khare',
#  'Dhruv Dev Dubey',
#  'Jayanth N',
#  'SREEDHAR',
#  'Ravi Dubey',
#  'Radha Manivasagam',
#  'Prateek Kumar',
#  'Amit Sharma',
#  'Kanan',
#  'Shashikant Chaudhary',
#  'Brad',
#  'Rutuja Pawar',
#  'Madhusudhan Sridhar',
#  'Ankit Sinha',
#  'Gaurav Chouhan',
#  'Rashi Kacker',
#  'Ashwini',
#  'Balaji Kolli',
# ...

# %%
search_designation=driver.find_elements_by_xpath("//span[@class='ellipsis clr']")
search_company=driver.find_elements_by_xpath("//a[@class='ellipsis']")
search_skill=driver.find_elements_by_xpath("//div[@class='hireSec highlightable']")
search_location=driver.find_elements_by_xpath("//small[@class='ellipsis']")

# %%
designation=[]
company=[]
skill=[]
location=[]

# %%
search_designation
search_company
search_skill
search_location
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="9b033153-9778-4121-9042-325baba83bcd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="6c6ea9c3-5b21-4e36-8b54-591369575b2b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="3e11a7d2-b1e7-4836-8a39-9eff3fb0b2e9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="f3d2b981-d945-4f25-be33-f2de5fee7fa8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="7cbd589c-e22f-4d41-9bbc-7efc015988ff")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="f9f2f2cf-ab51-417d-b6a3-da2cca25af92")>,
# ...

# %%
for i in search_designation:
    designation.append(i.text)
designation
# Out:
# ['HR Manager',
#  'Company Recruiter',
#  'Company HR',
#  'Company Recruiter',
#  'Founder CEO',
#  'Recruitment Lead Consultant',
#  'Programme Manager',
#  'HR Administrator',
#  'Director',
#  'Human Resource',
#  'HR Manager',
#  'Executive Hiring',
#  'Company HR',
#  'Company HR',
#  'Senior Executive Talent Acquisition',
#  'HR Team Lead',
#  'HR Manager',
#  'HR Executive',
#  'Manager Talent Acquisition',
#  'HR Head',
#  'HR MANAGER',
#  'HR Recruiter',
#  'HR Recruiter',
#  'Manager Human Resources',
#  'Company Recruiter',
#  'Lead Talent acquisition',
#  'Proprietor',
#  'CEO',
#  'Founder CEO',
#  'Senior Manager',
#  'Company Recruitment Head',
#  'Project Manager',
#  'Recruitment Consultant',
#  'Recruitment Manager',
#  'HR Executive',
#  'Head',
#  'Consultant',
#  'senior technology instructor',
#  'HR Recruiter/HR Excutive',
#  'Manager, Technical Recruiting',
#  'Technical Recruiter',
#  'Erp Implementer',
#  'Head Analytics',
#  'Chief Technical Officer',
# ...

# %%
for i in search_company:
    company.append(i.text)
company
# Out:
# ['Aakash Harit',
#  'Data Science Network',
#  'shravan Kumar Gaddam',
#  'Shore Infotech India Pvt. Ltd',
#  'MARSIAN Technologies LLP',
#  'MARSIAN Technologies LLP',
#  'Anik Agrawal',
#  'Enerlytics Software Solutions Pvt Ltd',
#  'subhas patel',
#  'LibraryXProject',
#  'Abhishek - Only Analytics Hiring - India and',
#  'Apidel Technologies Division of Transpower',
#  'Institute for Financial Management and Resear',
#  'IFMR',
#  'Balu Ramesh',
#  'Techvantage Systems Pvt Ltd',
#  'Asif Lucknowi',
#  'Weupskill- Live Wire India',
#  'InstaFinancials',
#  'CBL Data Science Private Limited',
#  'Priyanka Akiri',
#  'Infinitive Software Solutions Pvt.Ltd.',
#  'Kalpana Dumpala',
#  'Innominds Software',
#  'Mubarak',
#  'MoneyTap',
#  'Kushal Rastogi',
#  'QuantMagnum Technologies Pvt. Ltd.',
#  'Ruchi Dhote',
#  'Bristlecone India Ltd',
#  'Mahesh Babu Channa',
#  'SocialPrachar.com',
#  'Kapil Devang',
#  'BISP Solutions',
#  'Manisha Yadav',
#  'Easi Tax',
#  'Riya Rajesh',
# ...

# %%
for i in search_skill:
    skill.append(i.text)
skill
# Out:
# ['Classic ASP Developer, Internet Marketing Professional, Data Science SME, Content Writers, SEO Professional, Revenue Professional',
#  '.Net, Java, Data Science, Linux Administration, Sql Server Development, Winforms, Wcf Services, Wpf, Telecom Engineering, Technical Management, Software',
#  'Data Science, Artificial Intelligence, Machine Learning, Business Analytics',
#  'Mean Stack, javascript, angularjs, mongodb, Web Services, rest, express, Node.js, Big Data, iot, Data Science, Cloud Computing, saas, Aws',
#  'Hadoop, Spark, Digital Strategy, Data Architecture, Command Center, Cdp, Dmp, Kafka, Data Science, Data Analysis, Big Data Analytics, Real Time Analysis, SQL',
#  'Analytics, Business Intelligence, Business Analytics, Predictive Modeling, Predictive Analytics, Data Science, Data Analysis, Data Analytics, Big Data, Big',
#  'Data Science',
# ...

# %%
for i in search_location:
    location.append(i.text) 
location
# Out:
# ['Delhi',
#  'Hyderabad / Secunderabad',
#  'Pune',
#  'Ahmedabad',
#  'UK - (london)',
#  'Vadodara / Baroda',
#  'Chennai',
#  'Trivandrum',
#  'Indore',
#  'Bengaluru / Bangalore',
#  'Hyderabad',
#  'Hyderabad / Secunderabad',
#  'Bengaluru / Bangalore',
#  'Mumbai',
#  'Pune',
#  'Hyderabad / Secunderabad',
#  'Bhopal',
#  'Navi Mumbai',
#  'Cochin',
#  'Delhi',
#  'Hyderabad / Secunderabad',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Bengaluru / Bangalore',
#  'Bengaluru / Bangalore',
#  'Delhi',
#  'Bengaluru / Bangalore',
#  'Bengaluru / Bangalore',
#  'Mysoru / Mysore',
#  'Hyderabad / Secunderabad',
#  'Ghaziabad',
#  'Bengaluru / Bangalore',
#  'Noida',
#  'New Delhi',
#  'Chennai',
#  'Aligarh',
#  'Salt Lake City',
#  'Pune',
#  'Bengaluru / Bangalore',
#  'Mumbai',
#  'Indore',
#  'Bengaluru / Bangalore',
#  'MYSORE',
#  'Hyderabad / Secunderabad',
#  'Bengaluru / Bangalore',
#  'Mumbai']

# %%
df=pd.DataFrame({"name":name[0:10],"designation":designation[0:10],"company":company[0:10],
                "skill":skill[0:10],"location":location[0:10]})
df
# Out:
#                                             name                  designation  \
# 0                                   Aakash Harit                   HR Manager
# 1                           shravan Kumar Gaddam            Company Recruiter
# 2                       MARSIAN Technologies LLP                   Company HR
# 3                                   Anik Agrawal            Company Recruiter
# 4                                   subhas patel                  Founder CEO
# 5   Abhishek - Only Analytics Hiring - India and  Recruitment Lead Consultant
# 6  Institute for Financial Management and Resear            Programme Manager
# 7                                    Balu Ramesh             HR Administrator
# 8                                  Asif Lucknowi                     Director
# 9                                InstaFinancials               Human Resource
#
#                                  company  \
# 0                           Aakash Harit
# ...

# %% [markdown]
# 6. Scrape the details of top 100 songs on billboard.com.
# Url = https://www.billboard.com/
# You have to find the following details:
# A) Song name
# B) Artist name
# C) Last week rank
# D) Peak rank
# E) Weeks on board
# Note: - From the home page you have to click on the charts option then hot 100-page link through code

# %%
url = "https://www.billboard.com/charts/hot-100"
driver.get(url)

# %%
Song_name = []
Artist_name = []
Last_week_rank = []
Peak_rank = []
Weeks_on_board = []

# %%
name = driver.find_elements_by_xpath("//span[@class='chart-element__information__song text--truncate color--primary']")

# %%
name
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="9e590f04-74d4-4584-95a1-3573a48071fb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="193c0c8a-df99-4848-bca4-4469dffafa4f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="ab248919-2b41-4ef2-b7d5-d5b4aaa7719a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="2e792251-7ad1-4997-b487-5830dbb3b2b9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="37e12f7c-17f5-4862-81d1-120a4d52427a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="a23b5070-4162-469d-bc4d-9757b2e51416")>,
# ...

# %%
for i in name:
    Song_name.append(i.text)
Song_name
# Out:
# ['Stay',
#  'Bad Habits',
#  'Good 4 U',
#  'Kiss Me More',
#  'Industry Baby',
#  'Levitating',
#  'Butter',
#  'Deja Vu',
#  'Montero (Call Me By Your Name)',
#  'Save Your Tears',
#  'Fancy Like',
#  'You Right',
#  'Essence',
#  'Need To Know',
#  'Leave The Door Open',
#  'Take My Breath',
#  'Rumors',
#  'Peaches',
#  'Heartbreak Anniversary',
#  'Blinding Lights',
#  'Leave Before You Love Me',
#  'Happier Than Ever',
#  'Forever After All',
#  'Waves',
#  'Every Chance I Get',
#  'Pepas',
#  'Thot Shit',
#  'Traitor',
#  "Beggin'",
#  'Arcade',
#  'Late At Night',
#  'Things A Man Oughta Know',
#  'Heat Waves',
#  'Chasing After You',
#  'Wockesha',
#  'Glad You Exist',
#  'Without You',
#  'Skate',
#  'Astronaut In The Ocean',
#  'Rapstar',
#  "We Didn't Have Much",
#  'Country Again',
#  'Famous Friends',
#  "If I Didn't Love You",
#  'Cold Beer Calling My Name',
#  'Lil Bit',
#  'Beautiful Mistakes',
#  'Summer Of Love',
#  'Matt Hardy 999',
#  'Whole Lotta Money',
# ...

# %%
name2 = driver.find_elements_by_xpath("//span[@class='chart-element__information__artist text--truncate color--secondary']")
name2
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="c9a1bb57-ba4d-4ac3-b6d7-6d59f81bd0d2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="92b959f6-b097-4d39-8648-56c908a05b0a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="a1185bc9-4ae5-455e-b97f-f3e1b1781add")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="a1360a1c-0c76-41a9-8ade-32e3d7d45bd3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="344373d0-86e6-474e-99d6-6869b7dc9657")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="2234b476-04c4-4ba4-ac1f-a94aad257561")>,
# ...

# %%
for i in name2:
    Artist_name.append(i.text)
Artist_name
# Out:
# ['The Kid LAROI & Justin Bieber',
#  'Ed Sheeran',
#  'Olivia Rodrigo',
#  'Doja Cat Featuring SZA',
#  'Lil Nas X & Jack Harlow',
#  'Dua Lipa',
#  'BTS',
#  'Olivia Rodrigo',
#  'Lil Nas X',
#  'The Weeknd & Ariana Grande',
#  'Walker Hayes',
#  'Doja Cat & The Weeknd',
#  'Wizkid Featuring Justin Bieber & Tems',
#  'Doja Cat',
#  'Silk Sonic (Bruno Mars & Anderson .Paak)',
#  'The Weeknd',
#  'Lizzo Featuring Cardi B',
#  'Justin Bieber Featuring Daniel Caesar & Giveon',
#  'Giveon',
#  'The Weeknd',
#  'Marshmello X Jonas Brothers',
#  'Billie Eilish',
#  'Luke Combs',
#  'Luke Bryan',
#  'DJ Khaled Featuring Lil Baby & Lil Durk',
#  'Farruko',
#  'Megan Thee Stallion',
#  'Olivia Rodrigo',
#  'Maneskin',
#  'Duncan Laurence',
#  'Roddy Ricch',
#  'Lainey Wilson',
#  'Glass Animals',
#  'Ryan Hurd With Maren Morris',
#  'Moneybagg Yo',
#  'Dan + Shay',
#  'The Kid LAROI',
#  'Silk Sonic (Bruno Mars & Anderson .Paak)',
#  'Masked Wolf',
#  'Polo G',
#  'Justin Moore',
# ...

# %%
rank = driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--last']")
rank
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="99c11ed9-7f08-4a58-b92c-d703594d27eb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="7848aafd-9346-476d-8095-2b308df4f1bf")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="c8f80769-4118-4b1f-9289-709e430c6660")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="ccfa9c66-0e74-4f11-abe2-ad9372d66bb3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="bb04e4d1-ae53-4a91-be0c-371f25418b25")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="a7aac08f-f963-482a-81ae-8d9fb7153aad")>,
# ...

# %%
for i in  rank:
    if i.text is None :
        Last_week_rank.append("--") 
    else:
        Last_week_rank.append(i.text)
Last_week_rank
# Out:
# ['1',
#  '2',
#  '3',
#  '5',
#  '7',
#  '6',
#  '8',
#  '9',
#  '10',
#  '11',
#  '12',
#  '17',
#  '16',
#  '20',
#  '15',
#  '13',
#  '4',
#  '14',
#  '19',
#  '21',
#  '23',
#  '18',
#  '25',
#  '30',
#  '24',
#  '33',
#  '27',
#  '29',
#  '42',
#  '38',
#  '26',
#  '37',
#  '34',
#  '44',
#  '35',
#  '22',
#  '32',
#  '31',
#  '36',
#  '28',
#  '47',
#  '43',
#  '40',
#  '48',
#  '50',
#  '39',
#  '41',
#  '-',
#  '-',
#  '49',
#  '51',
#  '55',
#  '46',
#  '58',
#  '45',
#  '-',
#  '54',
#  '56',
#  '57',
#  '-',
#  '52',
#  '60',
#  '67',
#  '53',
#  '59',
#  '62',
#  '-',
#  '75',
#  '-',
#  '68',
#  '64',
#  '69',
#  '-',
#  '71',
#  '-',
#  '63',
#  '72',
#  '-',
#  '-',
#  '77',
#  '70',
#  '61',
#  '73',
#  '76',
#  '74',
#  '-',
#  '65',
#  '80',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '87',
#  '-',
#  '66',
#  '85',
#  '-',
#  '91']

# %%
rank2 = driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--peak']")
rank2
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="3c48e107-5c4a-443f-99e5-2e497da72125")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="3ce7b531-9deb-4e73-970c-323831c45c5c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="85425571-7769-4a7c-b448-e620e2b7dfd9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="cf10e78a-5f67-46ab-98c7-63639293e7ad")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="7e48302e-3e58-43aa-88d8-8caa8ea7ce5a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="886219d1-8080-43c1-887e-8ddd11a7df56")>,
# ...

# %%
for i in  rank2:
    if i.text is None :
        Peak_rank.append("--") 
    else:
        Peak_rank.append(i.text)
Peak_rank
# Out:
# ['1',
#  '2',
#  '1',
#  '3',
#  '2',
#  '2',
#  '1',
#  '3',
#  '1',
#  '1',
#  '11',
#  '11',
#  '13',
#  '14',
#  '1',
#  '6',
#  '4',
#  '1',
#  '16',
#  '1',
#  '19',
#  '11',
#  '2',
#  '24',
#  '20',
#  '26',
#  '16',
#  '9',
#  '29',
#  '30',
#  '20',
#  '32',
#  '19',
#  '34',
#  '33',
#  '21',
#  '8',
#  '14',
#  '6',
#  '1',
#  '41',
#  '42',
#  '21',
#  '15',
#  '45',
#  '23',
#  '13',
#  '48',
#  '49',
#  '16',
#  '51',
#  '52',
#  '24',
#  '54',
#  '22',
#  '56',
#  '32',
#  '10',
#  '14',
#  '60',
#  '26',
#  '53',
#  '63',
#  '13',
#  '24',
#  '50',
#  '67',
#  '68',
#  '69',
#  '68',
#  '42',
#  '11',
#  '73',
#  '71',
#  '75',
#  '63',
#  '72',
#  '50',
#  '11',
#  '76',
#  '70',
#  '58',
#  '64',
#  '76',
#  '74',
#  '86',
#  '65',
#  '80',
#  '12',
#  '90',
#  '91',
#  '92',
#  '93',
#  '94',
#  '87',
#  '96',
#  '1',
#  '41',
#  '99',
#  '91']

# %%
board = driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--week']")
board
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="af581aa4-518d-4106-a0fc-f2d135e2b291")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="93674a5c-3d1a-485f-94e7-b59fb3c9d8cf")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="88d8ebad-a61f-40bb-bbdd-25c0ad4e66d5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="d948e0b2-b965-4f40-ab92-e86db73795c3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="daa410a9-8e4a-4933-b672-d06b7a3c6edf")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="a0f89ff5-d984-4230-bfae-21bc34f5bf76")>,
# ...

# %%
for i in  board:
    if i.text is None :
        Weeks_on_board.append("--") 
    else:
        Weeks_on_board.append(i.text)
Weeks_on_board
# Out:
# ['7',
#  '9',
#  '15',
#  '20',
#  '5',
#  '47',
#  '14',
#  '21',
#  '22',
#  '37',
#  '10',
#  '9',
#  '8',
#  '11',
#  '25',
#  '3',
#  '2',
#  '23',
#  '28',
#  '90',
#  '14',
#  '4',
#  '44',
#  '10',
#  '17',
#  '5',
#  '11',
#  '14',
#  '9',
#  '20',
#  '12',
#  '15',
#  '32',
#  '17',
#  '18',
#  '29',
#  '38',
#  '4',
#  '28',
#  '20',
#  '10',
#  '17',
#  '22',
#  '5',
#  '8',
#  '23',
#  '25',
#  '1',
#  '1',
#  '7',
#  '6',
#  '8',
#  '13',
#  '6',
#  '4',
#  '1',
#  '13',
#  '12',
#  '6',
#  '1',
#  '17',
#  '18',
#  '8',
#  '7',
#  '9',
#  '7',
#  '1',
#  '3',
#  '1',
#  '4',
#  '5',
#  '22',
#  '1',
#  '4',
#  '1',
#  '8',
#  '5',
#  '3',
#  '11',
#  '4',
#  '9',
#  '11',
#  '12',
#  '3',
#  '4',
#  '1',
#  '2',
#  '4',
#  '11',
#  '1',
#  '1',
#  '1',
#  '1',
#  '1',
#  '3',
#  '1',
#  '7',
#  '9',
#  '1',
#  '2']

# %%
df=pd.DataFrame({"Song_name":Song_name[0:100],"Artist_name":Artist_name[0:100],"Last_week_rank":Last_week_rank[0:100],
                "Peak_rank":Peak_rank[0:100],"Weeks_on_board":Weeks_on_board[0:100]})
df
# Out:
#               Song_name                                        Artist_name  \
# 0                  Stay                      The Kid LAROI & Justin Bieber
# 1            Bad Habits                                         Ed Sheeran
# 2              Good 4 U                                     Olivia Rodrigo
# 3          Kiss Me More                             Doja Cat Featuring SZA
# 4         Industry Baby                            Lil Nas X & Jack Harlow
# ..                  ...                                                ...
# 95            Tick Tock                                         Young Thug
# 96  Permission To Dance                                                BTS
# 97                   AM                  Nio Garcia X J Balvin X Bad Bunny
# 98           Time Heals                                           Rod Wave
# 99   Thinking 'Bout You  Dustin Lynch Featuring Lauren Alaina Or MacKen...
#
#    Last_week_rank Peak_rank Weeks_on_board
# ...

# %% [markdown]
# 2.Scrape the details team India’s international fixtures from bcci.tv.
# Url = https://www.bcci.tv/.
# You need to find following details:
# A) Match title (I.e. 1st ODI)
# B) Series
# C) Place
# D) Date
# E) Time
# Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
url = "https://www.bcci.tv/international/fixtures"
driver.get(url)

# %%
search_International=driver.find_element_by_xpath("//div[@class='navigation__drop-down drop-down drop-down--reveal-on-hover']")
search_International
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="609a0cc9-ec76-480d-8567-b76e577574cf")>

# %%
search_International.click()

# %%
search_International.send_keys("FIXTURES")

# %%
Match_title = []
Series = []
Place = []
Date = []
Time = []

# %%
title = driver.find_elements_by_xpath("//span[@class='u-unskewed-text fixture__tournament-label u-truncated']")
title
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="53c7cca9-6f87-4f86-9597-713d4e0dafa3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="09b01ffa-4368-4846-a4fb-ef8b2a4db084")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="88413a86-e2e0-4a17-83d0-02e12dabd516")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="1ea85cd8-ffb8-44e8-9e8e-4fa8c726b573")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="20db122b-1d90-4ab1-8609-9f9828bc57b0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="034620ef-a00f-4213-8c45-1016a460456e")>]

# %%
for i in title:
    Match_title.append(i.text)
Match_title
# Out:
# ['ENGLAND V INDIA 2021',
#  "2021 ICC MEN'S T20 WORLD CUP",
#  "2021 ICC MEN'S T20 WORLD CUP",
#  "2021 ICC MEN'S T20 WORLD CUP",
#  "2021 ICC MEN'S T20 WORLD CUP",
#  "2021 ICC MEN'S T20 WORLD CUP"]

# %%
Pla = driver.find_elements_by_xpath("//p[@class='fixture__additional-info']")

# %%
Pla
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="a6eb07d9-1fa7-4b6c-afe2-9da8b17e758e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="c0c3fd89-208d-4913-aa99-ef75c67058d9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="1ddd001e-0ab5-4272-804c-241fc7b3b6da")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="205437f7-503d-4581-acd3-3f86e6d348e1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="ac340393-1dc0-49d4-8260-3a0befa8f9a1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="6a065667-a9e6-442c-86cb-b2d2bdd3a409")>]

# %%
for i in Pla:
    Place.append(i.text)
Place
# Out:
# ['5th Test\nOld Trafford, Manchester',
#  'Match 16\nDubai International Cricket Stadium, Dubai',
#  'Match 28\nDubai International Cricket Stadium, Dubai',
#  'Match 33\nSheikh Zayed Cricket Stadium, Abu Dhabi',
#  'Match 37\nDubai International Cricket Stadium, Dubai',
#  'Match 42\nDubai International Cricket Stadium, Dubai']

# %%
Date1 = driver.find_elements_by_xpath("//span[@class='fixture__date']")

# %%
Date1
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="30d20db3-dffb-4e9c-9cdd-8a47325f2719")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="4dbc31b9-a63c-4429-9532-d094bd76e05e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="581ffdd9-afbb-4602-a524-ef91ff0abbdd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="73449f94-b865-470e-b19a-dcd19352e31d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="c633f62b-4c2c-4237-b08a-018b4063aa7a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="9d4ab3bf-3a67-439f-bcf7-e83dbef9ca94")>]

# %%
for i in Date1:
    Date.append(i.text)
Date
# Out:
# ['10', '24', '31', '03', '05', '08']

# %%
Time1 = driver.find_elements_by_xpath("//span[@class='fixture__time']")
Time1
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="89024cd0-339f-4f4a-a643-cc5772280002")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="7f8907d3-0144-434e-b9e9-8d1a32c3e509")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="cc046a90-1d77-45bb-8752-59c72c3c02ce")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="c733747c-7948-47ee-aa70-3b887ae7f5ec")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="9e043556-84a0-41bb-8b5f-6acb62dd3e79")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="d50e5c79-27a1-4afe-b27a-9b20f995525d")>]

# %%
for i in Time1:
    Time.append(i.text)
Time
# Out:
# ['15:30 IST', '19:30 IST', '19:30 IST', '19:30 IST', '19:30 IST', '19:30 IST']

# %%
df=pd.DataFrame({"Match_title":Match_title[0:10],"Place":Place[0:10],"Date":Date[0:10],
                "Time":Time[0:10]})
df
# Out:
#                     Match_title  \
# 0          ENGLAND V INDIA 2021
# 1  2021 ICC MEN'S T20 WORLD CUP
# 2  2021 ICC MEN'S T20 WORLD CUP
# 3  2021 ICC MEN'S T20 WORLD CUP
# 4  2021 ICC MEN'S T20 WORLD CUP
# 5  2021 ICC MEN'S T20 WORLD CUP
#
#                                                Place Date       Time
# 0                 5th Test\nOld Trafford, Manchester   10  15:30 IST
# 1  Match 16\nDubai International Cricket Stadium,...   24  19:30 IST
# 2  Match 28\nDubai International Cricket Stadium,...   31  19:30 IST
# 3  Match 33\nSheikh Zayed Cricket Stadium, Abu Dhabi   03  19:30 IST
# 4  Match 37\nDubai International Cricket Stadium,...   05  19:30 IST
# 5  Match 42\nDubai International Cricket Stadium,...   08  19:30 IST

# %% [markdown]
# 1. Scrape the details of most viewed videos on YouTube from Wikipedia:
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos/
# You need to find following details:
# A) Rank
# B) Name
# C) Artist
# D) Upload date
# E) Views

# %%
url = "https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos/"
driver.get(url)

# %%
Rank = []
Name = []
Artist = []
Upload_date = []
Views = []

# %%
List = driver.find_elements_by_xpath("//div[@id='mw-content-text']")

# %%
List
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="f780254bce4d7543603209128cde88f4", element="b71f4ddb-765e-485a-b3a5-0906b89f784d")>]
